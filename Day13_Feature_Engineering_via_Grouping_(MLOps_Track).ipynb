# %% [markdown]
# <a href="https://colab.research.google.com/github/sh1618112233/12-Weeks-to-ML/blob/main/Day13_Feature_Engineering_via_Grouping_(MLOps_Track).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

report = pd.read_csv('https://github.com/StackExchange/Survey/raw/refs/heads/main/packages/archive/2025/results.csv')

creport = report.dropna(subset=['ConvertedCompYearly'])

groupedcountry = creport.groupby('Country')

groupedcountry.count()

groupedcountry['ConvertedCompYearly'].agg(['median' , 'count'])


creport['Country_Median_Pay'] = groupedcountry['ConvertedCompYearly'].transform('median')
creport

creport['DeviationFromNorm'] = creport['ConvertedCompYearly'] - creport['Country_Median_Pay']


groupedcountry[['Country', 'ConvertedCompYearly', 'Country_Median_Pay', 'DeviationFromNorm']].head(10)
# Out:
# /tmp/ipykernel_7339/2687602668.py:4: DtypeWarning: Columns (56,74,92,97,98,105,109,110,132,162,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   report = pd.read_csv('https://github.com/StackExchange/Survey/raw/refs/heads/main/packages/archive/2025/results.csv')
# /tmp/ipykernel_7339/2687602668.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   creport['Country_Median_Pay'] = groupedcountry['ConvertedCompYearly'].transform('median')
# /tmp/ipykernel_7339/2687602668.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
